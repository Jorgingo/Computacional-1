# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mplt
import pylab as plt
from pylab import figure, show, legend, xlabel, ylabel

# %%
df = pd.read_csv("/home/elmadafaka/Física_computacional/Actividad_4/16feb.csv")

# %%
df.columns= ['Presión','Altitud','Temperatura','DWPT','RELH','MIXR','DRCT','SKNT','THTA','THTE','THTV']

# %%
df.head(10)
# Out:
#    Presión  Altitud  Temperatura  DWPT  RELH   MIXR   DRCT  SKNT   THTA  \
# 0   1000.0      121         18.8  14.0    74  10.14    0.0   2.0  291.9
# 1    979.0      300         17.2  13.6    79  10.07  275.0   5.0  292.1
# 2    925.0      780         13.0  12.4    96   9.87  225.0   9.0  292.6
# 3    917.0      853         12.4  11.7    95   9.50  215.0   9.0  292.7
# 4    908.0      935         12.8   8.4    75   7.67  203.0   9.0  293.9
# 5    880.0     1196         10.9   7.2    78   7.27  165.0   9.0  294.6
# 6    852.0     1465          9.0   5.9    81   6.88  174.0  11.0  295.4
# 7    850.0     1484          9.0   5.9    81   6.89  175.0  11.0  295.6
# 8    821.0     1772          8.4   2.4    66   5.57  180.0  11.0  297.9
# 9    789.0     2098          5.8   1.9    76   5.58  185.0  11.0  298.5
#
#     THTE   THTV
# 0  320.9  293.7
# 1  320.9  293.9
# 2  320.9  294.3
# 3  320.0  294.4
# 4  316.3  295.3
# 5  315.9  295.9
# 6  315.6  296.6
# 7  315.9  296.8
# 8  314.6  298.9
# 9  315.2  299.5

# %%
x=df[u'Altitud']
y=df[u'Presión']

# %%
mplt.plot(x,y)
mplt.grid(True)
plt.xlabel('Altura (m)')
plt.ylabel('Presión (hPa)')
plt.title('Presión en relación a la altura')

# %%
plt.show()

# %%
x=df[u'Altitud']
y=df[u'Temperatura']

# %%
mplt.plot(x,y)
mplt.grid(True)
plt.xlabel('Altitud (m)')
plt.ylabel('Temperatura (°C)')
plt.title('Temperatura en relación a la altura')

# %%
plt.show()

# %%
x=df[u'Altitud']
y=df[u'DWPT']

# %%
mplt.plot(x,y)
mplt.grid(True)
plt.xlabel('Altitud')
plt.ylabel('DWPT (°C)')
plt.title('Temperatura de rocío en relación a la altura')

# %%
plt.show()

# %%
x=df[u'Altitud']
y=df[u'Temperatura']
mplt.plot(x,y, label='Presión vs DWPT', color='green')
mplt.grid(True)

# %%
x=df[u'Altitud']
y=df[u'DWPT']
mplt.plot(x,y, label='Presión vs DWPT', color='blue')
mplt.grid(True)
plt.title('Temperatura y temperatura de rocío')
plt.xlabel('Altura')
plt.ylabel('Temperatura')

# %%
plt.show()

# %%
import tephi as tph

# %%
import os.path

# %%
df_1=pd.read_csv('DWPT.txt', sep=" ", header = None)

# %%
df_1.columns= ['Presión','DWPT']

# %%
df_1.head()
# Out:
#    Presión  DWPT
# 0   1013.0  14.4
# 1   1000.0  14.0
# 2    979.0  13.6
# 3    925.0  12.4
# 4    917.0  11.7

# %%
import os.path

import tephi as tephi

dew_point=pd.read_csv('DWPT.csv', names=['Presión','DWPT'])
temp=pd.read_csv('Temperatura.csv', names=['Presión','Temperatura'])

# %%
dew_point.head()
# Out:
#    Presión  DWPT
# 0   1013.0  14.4
# 1   1000.0  14.0
# 2    979.0  13.6
# 3    925.0  12.4
# 4    917.0  11.7

# %%
temp.head()
# Out:
#    Presión  Temperatura
# 0   1013.0         18.8
# 1   1000.0         18.8
# 2    979.0         17.2
# 3    925.0         13.0
# 4    917.0         12.4

# %%
tpg=tephi.Tephigram()
tpg.plot(dew_point)
tpg.plot(temp, label='Presión vs Temperatura', color='blue')

# %%
plt.show()
